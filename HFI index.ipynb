# %%
#potential useful libraries to use

import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
#import files 
hfi_2018 = pd.read_csv('./datasets/archive/hfi_cc_2018.csv')

# %%
hfi_2018.head()
# Out:
#    year ISO_code  countries                         region  pf_rol_procedural  \
# 0  2016      ALB    Albania                 Eastern Europe           6.661503
# 1  2016      DZA    Algeria     Middle East & North Africa                NaN
# 2  2016      AGO     Angola             Sub-Saharan Africa                NaN
# 3  2016      ARG  Argentina  Latin America & the Caribbean           7.098483
# 4  2016      ARM    Armenia        Caucasus & Central Asia                NaN
#
#    pf_rol_civil  pf_rol_criminal    pf_rol  pf_ss_homicide  \
# 0      4.547244         4.666508  5.291752        8.920429
# 1           NaN              NaN  3.819566        9.456254
# 2           NaN              NaN  3.451814        8.060260
# 3      5.791960         4.343930  5.744791        7.622974
# 4           NaN              NaN  5.003205        8.808750
#
#    pf_ss_disappearances_disap  ...  ef_regulation_business_bribes  \
# 0                        10.0  ...                       4.050196
# ...

# %%
#shows all 123 columns on the dataframe
pd.set_option('display.max_columns', None)

# %%
hfi_2018.head()
# Out:
#    year ISO_code  countries                         region  pf_rol_procedural  \
# 0  2016      ALB    Albania                 Eastern Europe           6.661503
# 1  2016      DZA    Algeria     Middle East & North Africa                NaN
# 2  2016      AGO     Angola             Sub-Saharan Africa                NaN
# 3  2016      ARG  Argentina  Latin America & the Caribbean           7.098483
# 4  2016      ARM    Armenia        Caucasus & Central Asia                NaN
#
#    pf_rol_civil  pf_rol_criminal    pf_rol  pf_ss_homicide  \
# 0      4.547244         4.666508  5.291752        8.920429
# 1           NaN              NaN  3.819566        9.456254
# 2           NaN              NaN  3.451814        8.060260
# 3      5.791960         4.343930  5.744791        7.622974
# 4           NaN              NaN  5.003205        8.808750
#
#    pf_ss_disappearances_disap  pf_ss_disappearances_violent  \
# 0                        10.0                      10.00000
# ...

# %%
hfi_2018.year.value_counts()
# Out:
# 2016    162
# 2015    162
# 2014    162
# 2013    162
# 2012    162
# 2011    162
# 2010    162
# 2009    162
# 2008    162
# Name: year, dtype: int64

# %%
hfi_2019 = pd.read_csv('./datasets/archive/hfi_cc_2019.csv')

# %%
hfi_2019.head()
# Out:
#    year ISO_code  countries                         region hf_score hf_rank  \
# 0  2017      ALB    Albania                 Eastern Europe     7.84      38
# 1  2017      DZA    Algeria     Middle East & North Africa     4.99     155
# 2  2017      AGO     Angola             Sub-Saharan Africa      5.4     151
# 3  2017      ARG  Argentina  Latin America & the Caribbean     6.86      77
# 4  2017      ARM    Armenia        Caucasus & Central Asia     7.42      54
#
#   hf_quartile pf_rol_procedural pf_rol_civil pf_rol_criminal pf_rol  \
# 0           1               6.7          4.5             4.7    5.3
# 1           4                 -            -               -    3.8
# 2           4                 -            -               -    3.4
# 3           2               7.1          5.8             4.3    5.7
# 4           2                 -            -               -    4.9
#
#   pf_ss_homicide pf_ss_disappearances_disap pf_ss_disappearances_violent  \
# ...

# %%
hfi_2019.year.value_counts()
# Out:
# 2017    162
# 2016    162
# 2015    162
# 2014    162
# 2013    162
# 2012    162
# 2011    162
# 2010    162
# 2009    162
# 2008    162
# Name: year, dtype: int64

# %% [markdown]
# Looking at the data, each iteration has one more year added plus all the previous data.

# %%
hfi_2021 = pd.read_csv('./datasets/archive/hfi_cc_2021.csv')

# %%
hfi_2021.head()
# Out:
#    year  countries  ISO                         region  hf_score  hf_rank  \
# 0  2019    Albania  ALB                 Eastern Europe      8.14     43.0
# 1  2019    Algeria  DZA     Middle East & North Africa      5.26    154.0
# 2  2019     Angola  AGO             Sub-Saharan Africa      6.09    129.0
# 3  2019  Argentina  ARG  Latin America & the Caribbean      7.38     74.0
# 4  2019    Armenia  ARM        Caucasus & Central Asia      8.20     40.0
#
#    hf_quartile  pf_rol_procedural  pf_rol_civil  pf_rol_criminal  pf_rol  \
# 0          2.0               5.97          4.76             4.26    5.00
# 1          4.0               5.21          5.64             4.35    5.07
# 2          4.0               2.72          4.43             3.60    3.58
# 3          2.0               6.83          5.94             4.35    5.71
# 4          1.0                NaN           NaN              NaN    4.98
#
#    pf_ss_homicide  pf_ss_disappearances_disap  pf_ss_disappearances_violent  \
# ...
